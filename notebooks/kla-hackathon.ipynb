# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')
# Out:
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/day1_setup.py
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/degradation_config.json
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/split.json
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0566.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0115.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0050.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0501.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0263.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0133.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0563.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0693.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0006.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0516.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0003.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0013.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0052.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0394.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0178.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0273.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0314.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0139.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0460.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0148.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0217.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0242.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0337.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0185.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0740.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0226.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0053.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0096.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0099.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0451.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0340.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0453.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0301.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0670.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0274.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0699.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0295.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0512.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0405.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0341.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0039.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0480.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0266.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0044.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0208.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0576.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0369.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0311.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0412.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0486.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0291.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0360.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0153.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0017.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0007.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0646.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0433.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0529.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0759.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0286.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0375.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0766.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0118.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0071.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0704.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0712.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0752.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0763.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0439.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0475.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0683.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0686.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0316.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0180.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0041.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0472.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0697.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0011.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0495.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0078.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0077.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0427.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0119.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0345.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0146.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0562.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0424.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0711.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0419.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0355.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0671.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0479.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0521.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0459.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0067.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0517.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0122.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0202.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0194.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0339.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0189.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0662.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0047.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0163.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0612.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0761.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0737.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0196.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0588.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0780.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0573.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0561.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0239.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0675.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0249.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0393.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0418.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0127.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0152.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0631.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0554.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0445.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0608.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0157.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0304.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0137.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0667.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0083.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0444.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0069.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0600.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0348.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0617.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0590.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0275.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0351.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0378.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0655.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0140.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0392.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0072.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0297.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0294.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0513.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0086.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0726.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0487.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0613.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0506.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0450.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0229.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0090.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0715.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0702.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0628.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0527.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0342.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0464.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0396.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0568.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0742.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0073.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0640.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0491.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0218.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0618.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0589.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0492.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0330.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0101.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0210.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0066.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0592.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0353.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0457.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0106.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0117.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0441.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0795.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0091.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0432.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0332.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0717.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0132.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0181.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0290.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0212.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0076.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0074.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0713.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0319.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0532.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0797.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0681.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0049.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0241.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0108.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0545.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0644.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0088.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0548.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0688.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0685.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0303.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0259.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0558.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0559.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0016.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0401.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0103.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0230.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0317.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0440.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0748.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0084.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0193.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0114.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0367.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0734.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0446.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0530.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0169.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0570.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0199.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0518.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0033.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0270.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0318.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0246.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0253.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0032.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0325.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0333.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0298.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0165.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0648.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0468.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0710.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0055.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0718.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0272.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0238.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0753.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0739.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0225.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0669.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0004.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0236.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0466.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0719.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0409.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0540.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0054.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0206.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0271.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0581.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0603.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0386.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0620.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0403.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0519.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0790.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0095.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0075.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0124.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0452.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0372.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0597.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0397.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0125.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0689.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0456.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0255.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0602.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0434.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0171.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0523.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0214.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0647.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0147.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0390.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0594.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0021.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0735.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0656.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0633.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0754.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0428.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0619.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0654.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0162.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0371.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0234.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0161.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0771.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0142.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0696.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0599.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0116.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0751.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0323.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0649.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0724.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0652.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0058.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0166.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0293.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0577.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0221.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0070.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0358.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0778.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0736.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0569.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0665.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0772.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0248.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0494.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0043.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0307.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0583.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0176.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0344.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0534.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0690.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0023.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0207.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0765.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0046.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0037.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0120.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0029.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0703.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0448.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0447.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0661.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0714.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0478.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0609.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0462.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0038.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0413.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0209.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0770.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0624.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0454.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0538.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0313.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0706.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0296.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0150.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0621.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0406.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0490.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0721.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0636.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0776.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0030.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0645.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0550.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0421.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0793.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0237.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0546.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0198.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0305.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0402.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0560.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0417.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0596.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0595.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0556.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0666.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0792.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0379.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0321.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0467.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0320.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0508.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0310.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0553.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0800.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0552.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0607.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0708.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0283.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0113.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0514.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0461.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0285.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0410.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0629.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0749.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0110.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0557.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0223.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0031.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0709.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0722.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0233.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0288.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0743.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0051.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0474.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0056.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0499.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0265.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0779.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0510.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0143.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0024.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0374.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0388.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0687.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0228.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0677.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0684.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0315.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0623.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0183.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0796.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0292.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0105.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0244.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0134.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0515.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0496.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0187.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0363.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0476.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0022.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0469.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0507.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0130.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0584.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0370.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0034.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0536.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0128.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0020.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0213.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0593.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0035.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0773.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0224.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0420.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0156.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0694.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0334.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0604.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0284.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0144.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0167.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0123.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0192.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0438.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0126.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0012.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0322.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0731.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0048.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0258.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0470.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0349.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0014.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0350.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0522.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0511.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0205.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0760.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0767.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0650.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0541.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0042.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0632.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0299.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0365.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0261.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0010.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0231.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0328.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0195.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0391.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0483.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0707.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0373.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0359.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0384.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0235.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0179.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0634.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0784.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0352.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0201.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0587.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0426.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0254.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0489.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0327.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0680.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0425.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0524.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0498.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0175.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0497.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0598.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0136.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0768.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0520.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0282.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0651.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0787.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0018.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0385.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0001.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0500.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0783.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0068.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0111.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0698.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0606.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0643.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0087.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0411.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0138.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0336.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0045.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0567.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0408.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0528.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0543.png
# ...
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000559.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002503.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001511.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000882.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000018.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001081.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002045.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002500.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002814.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000978.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002773.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001592.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000023.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001793.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000080.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000665.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002817.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002136.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/003032.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001614.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002711.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000632.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001281.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002178.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/003046.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000565.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002454.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000000.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001279.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/003141.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000732.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000181.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002632.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000583.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002874.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001653.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002422.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002047.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000400.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001884.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001358.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001525.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002066.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000764.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002526.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002554.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000534.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001735.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002330.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/003049.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000449.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002644.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002150.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001823.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002565.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000299.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002802.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002933.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001327.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000087.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002258.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000500.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000889.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002609.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001366.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001762.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001443.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/003053.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001933.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002232.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000870.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001499.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001846.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000468.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001807.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001237.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002476.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000065.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000144.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000042.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000480.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001338.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001707.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002491.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001562.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001238.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001293.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001299.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002810.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000544.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002074.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002670.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001781.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000494.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002515.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001125.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000674.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000536.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000032.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001329.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002791.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001497.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000126.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000171.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000147.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002213.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001875.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000705.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001118.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002493.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000830.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001512.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001910.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001683.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001354.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002782.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002430.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001969.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000675.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001799.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002215.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001865.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000343.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001648.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001769.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002619.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001761.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000509.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/003139.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001657.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000653.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001346.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000591.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000702.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000078.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000637.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002374.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000806.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002816.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002318.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000113.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001782.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002803.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002982.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/003163.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002128.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002857.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001931.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001678.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/003012.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002439.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000634.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002867.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002763.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002812.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002553.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000473.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002405.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000019.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000035.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000302.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000291.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002363.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000487.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001821.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001945.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001534.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001453.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002245.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001909.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001702.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000378.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002606.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000829.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001129.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001037.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001086.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000250.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/003148.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000854.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000612.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000138.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001932.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000357.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/003116.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000011.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001337.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002487.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000861.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000658.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/002527.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/003110.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001186.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/000149.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR/001412.npy

# %%
# !find /kaggle/input-maxdepth 4 -type d|head -40
# Out:
# find: ‘/kaggle/input-maxdepth’: No such file or directory
# find: ‘4’: No such file or directory

# %%
# !find /kaggle/input -maxdepth 4 -type d | head -40
# Out:
# /kaggle/input
# /kaggle/input/datasets
# /kaggle/input/datasets/aarushsingh2007
# /kaggle/input/datasets/aarushsingh2007/kla-dataset
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/files
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train

# %%
# !ls /kaggle/input/datasets/aarushsingh2007/kla-dataset/train /kaggle/input/datasets/aarushsingh2007/kla-dataset/files
# !ls /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR | head -3
# !ls /kaggle/input/datasets/aarushsingh2007/kla-dataset/*.json
# Out:
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/files:
# make_training_data.py  nafnet_sr.py  train.py
#
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train:
# train
# DIV2K_train_HR
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/degradation_config.json
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/split.json

# %%
BASE = '/kaggle/input/datasets/aarushsingh2007/kla-dataset'
# !find {BASE} -maxdepth 5 -type d | head -20
# !find {BASE} -name "*.npy" | head -2
# !find {BASE} -name "*.png" | head -2
# Out:
# /kaggle/input/datasets/aarushsingh2007/kla-dataset
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/files
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/GT
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/NoisyLR
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/GT/001314.npy
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/train/train/GT/002909.npy
# find: ‘standard output’: Broken pipe
# find: write error
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0566.png
# /kaggle/input/datasets/aarushsingh2007/kla-dataset/DIV2K_train_HR/DIV2K_train_HR/0115.png
# find: ‘standard output’: Broken pipe
# find: write error

# %%
BASE = '/kaggle/input/datasets/aarushsingh2007/kla-dataset'

# !cp {BASE}/files/*.py .
# !python train.py \
  --gt_dir {BASE}/train/train/GT \
  --lr_dir {BASE}/train/train/NoisyLR \
  --split {BASE}/split.json \
  --extra_dir {BASE}/DIV2K_train_HR/DIV2K_train_HR \
  --size w32 --epochs 2 --batch 16 --workers 4 \
  --out /kaggle/working/checkpoints
# Out:
# device: cuda
#   KLA pairs: 3200  ->  train 2720, val 480
#   outside photos: 800 x4 = 3200
#   training samples per epoch: 8640
# model: NAFNet-SR w32, 29.16M parameters
#
# bicubic baseline on val: PSNR 22.15 dB   SSIM 0.5410
# your model must beat this.
#
# epoch   1/2  loss 0.1060  val PSNR 22.41 (+0.26 vs bicubic)  SSIM 0.5476  864s   <- best, saved
# epoch   2/2  loss 0.0978  val PSNR 22.67 (+0.52 vs bicubic)  SSIM 0.5544  863s   <- best, saved
#
# best val PSNR 22.67 dB -> /kaggle/working/checkpoints/best.pt

# %%
# %%writefile train.py
"""
Trains NAFNet-SR for the KLA image restoration challenge.

What it trains on
-----------------
Three sources, mixed together every epoch:

  1. KLA's real pairs, used exactly as given. Keeps you anchored to the truth.
  2. KLA's clean images, re-damaged fresh each time with random settings.
  3. Outside photos (DIV2K etc.), also damaged fresh each time.

Sources 2 and 3 are what make the model cope with images it has never seen,
which is half the score. Source 1 stops it drifting away from the real problem.

How it is scored while training
-------------------------------
Validation always uses KLA's REAL damaged files, never synthetic ones, on the
photos held out by day1_setup.py. That number is the honest one.

Run it
------
    python train.py --smoke_test        # ~1 minute, checks everything works

    python train.py --gt_dir GT --lr_dir NoisyLR --split split.json \
                    --extra_dir DIV2K_train_HR --size w32 --epochs 60
"""

import argparse
import glob
import json
import os
import time

import numpy as np
import torch
import torch.nn.functional as F
from torch.utils.data import ConcatDataset, DataLoader, Dataset

from make_training_data import degrade, minmax
from nafnet_sr import NAFNetSR, get_device

IMG_EXT = ('.png', '.jpg', '.jpeg', '.bmp', '.tif', '.tiff')


# ----------------------------------------------------------------------
# data
# ----------------------------------------------------------------------

def load_gray(path):
    """Load a .npy array or an ordinary image file as greyscale floats."""
    if path.lower().endswith('.npy'):
        a = np.load(path).astype(np.float64)
    else:
        from PIL import Image
        a = np.asarray(Image.open(path).convert('L')).astype(np.float64) / 255.0
    return np.nan_to_num(a, nan=0.0, posinf=0.0, neginf=0.0)


class PairDataset(Dataset):
    """mode='real'      -> KLA's own damaged files, untouched
       mode='synthetic' -> clean image damaged fresh on every access
    """

    def __init__(self, gt_paths, lr_paths=None, mode='synthetic',
                 crop=256, augment=True, seed=None):
        self.gt = list(gt_paths)
        self.lr = list(lr_paths) if lr_paths else None
        self.mode = mode
        self.crop = crop
        self.augment = augment
        self.seed = seed
        if mode == 'real' and not self.lr:
            raise ValueError("mode='real' needs lr_paths")

    def __len__(self):
        return len(self.gt)

    def __getitem__(self, i):
        # A fixed seed makes validation identical every epoch, so the numbers are
        # comparable run to run. Training leaves it None so the noise is fresh.
        rng = (np.random.default_rng(self.seed + i) if self.seed is not None
               else np.random.default_rng())

        gt = load_gray(self.gt[i])

        if self.mode == 'real':
            lr = load_gray(self.lr[i])
        else:
            if self.crop and min(gt.shape) > self.crop:
                y = int(rng.integers(0, gt.shape[0] - self.crop + 1))
                x = int(rng.integers(0, gt.shape[1] - self.crop + 1))
                gt = gt[y:y + self.crop, x:x + self.crop]
            # Every GT image KLA supplied is stretched to exactly [0,1].
            # Matching that keeps synthetic pairs statistically identical.
            gt = minmax(gt)
            lr, _ = degrade(gt, rng=rng, blur=bool(rng.random() < 0.1))

        if self.augment:
            if rng.random() < 0.5:
                gt, lr = gt[:, ::-1], lr[:, ::-1]
            if rng.random() < 0.5:
                gt, lr = gt[::-1], lr[::-1]
            k = int(rng.integers(4))
            if k:
                gt, lr = np.rot90(gt, k), np.rot90(lr, k)

        gt = torch.from_numpy(np.ascontiguousarray(gt, dtype=np.float32))[None]
        lr = torch.from_numpy(np.ascontiguousarray(lr, dtype=np.float32))[None]
        return lr, gt


# ----------------------------------------------------------------------
# losses and metrics
# ----------------------------------------------------------------------

class Charbonnier(torch.nn.Module):
    """Smoothed absolute error. Steadier than squared error, sharper than plain L1."""

    def __init__(self, eps=1e-3):
        super().__init__()
        self.e2 = eps ** 2

    def forward(self, p, t):
        return torch.sqrt((p - t) ** 2 + self.e2).mean()


def fft_loss(pred, target):
    """Compares the two images by their frequency content.

    This is what stops the model cheating. Blurring is an easy way to make grain
    vanish, and pixel losses barely punish it. Blurring destroys high frequencies,
    which this term notices immediately.
    """
    pf = torch.fft.rfft2(pred.float(), norm='ortho')
    tf = torch.fft.rfft2(target.float(), norm='ortho')
    return (torch.view_as_real(pf) - torch.view_as_real(tf)).abs().mean()


def _gauss_window(ws=11, sigma=1.5, device='cpu', dtype=torch.float32):
    c = torch.arange(ws, device=device, dtype=dtype) - (ws - 1) / 2
    g = torch.exp(-(c ** 2) / (2 * sigma ** 2))
    g = g / g.sum()
    return (g[:, None] @ g[None, :])[None, None]


def ssim(pred, target, ws=11, C1=0.01 ** 2, C2=0.03 ** 2):
    """Structural similarity, one of the three scores KLA uses. 1.0 is perfect."""
    pred, target = pred.float(), target.float()
    w = _gauss_window(ws, device=pred.device, dtype=pred.dtype)
    pad = ws // 2
    mu1 = F.conv2d(pred, w, padding=pad)
    mu2 = F.conv2d(target, w, padding=pad)
    mu1s, mu2s, mu12 = mu1 ** 2, mu2 ** 2, mu1 * mu2
    s1 = F.conv2d(pred * pred, w, padding=pad) - mu1s
    s2 = F.conv2d(target * target, w, padding=pad) - mu2s
    s12 = F.conv2d(pred * target, w, padding=pad) - mu12
    num = (2 * mu12 + C1) * (2 * s12 + C2)
    den = (mu1s + mu2s + C1) * (s1 + s2 + C2)
    return (num / den).mean()


def psnr(pred, target):
    """Higher is better; +1 dB is a solid gain.

    Clamped to [0,1] first because every KLA ground-truth image lives in exactly
    that range, so anything outside it is pure error.
    """
    mse = F.mse_loss(pred.clamp(0, 1).float(), target.float())
    return 10 * torch.log10(1.0 / mse.clamp_min(1e-12))


class TotalLoss(torch.nn.Module):
    def __init__(self, w_fft=0.05, w_ssim=0.10):
        super().__init__()
        self.char = Charbonnier()
        self.w_fft = w_fft
        self.w_ssim = w_ssim

    def forward(self, pred, target):
        loss = self.char(pred, target)
        if self.w_fft:
            loss = loss + self.w_fft * fft_loss(pred, target)
        if self.w_ssim:
            loss = loss + self.w_ssim * (1 - ssim(pred.clamp(0, 1), target))
        return loss


# ----------------------------------------------------------------------
# train / validate
# ----------------------------------------------------------------------

@torch.no_grad()
def validate(model, loader, device):
    model.eval()
    ps, ss, n = 0.0, 0.0, 0
    for lr, gt in loader:
        lr, gt = lr.to(device), gt.to(device)
        out = model(lr).clamp(0, 1)
        b = lr.shape[0]
        ps += float(psnr(out, gt)) * b
        ss += float(ssim(out, gt)) * b
        n += b
    model.train()
    return ps / max(n, 1), ss / max(n, 1)


@torch.no_grad()
def baseline_scores(loader, device, scale=2):
    """What plain bicubic upscaling gets. The model must beat this, or something
    is broken. Cheapest possible sanity check."""
    ps, ss, n = 0.0, 0.0, 0
    for lr, gt in loader:
        lr, gt = lr.to(device), gt.to(device)
        up = F.interpolate(lr, scale_factor=scale, mode='bicubic',
                           align_corners=False).clamp(0, 1)
        b = lr.shape[0]
        ps += float(psnr(up, gt)) * b
        ss += float(ssim(up, gt)) * b
        n += b
    return ps / max(n, 1), ss / max(n, 1)


def build_loaders(a):
    gt_files = sorted(glob.glob(os.path.join(a.gt_dir, '*.npy')))
    lr_files = [os.path.join(a.lr_dir, os.path.basename(f)) for f in gt_files]
    keep = [i for i, f in enumerate(lr_files) if os.path.exists(f)]
    gt_files = [gt_files[i] for i in keep]
    lr_files = [lr_files[i] for i in keep]
    if not gt_files:
        raise SystemExit('No matching GT / NoisyLR pairs found. Check the paths.')

    split = json.load(open(a.split))
    tr_idx = [i for i in split['train'] if i < len(gt_files)]
    va_idx = [i for i in split['val_hard'] if i < len(gt_files)]
    print(f'  KLA pairs: {len(gt_files)}  ->  train {len(tr_idx)}, val {len(va_idx)}')

    sets = [
        # 1. the real pairs, untouched
        PairDataset([gt_files[i] for i in tr_idx], [lr_files[i] for i in tr_idx],
                    mode='real', crop=None),
        # 2. the same clean images, re-damaged fresh every time
        PairDataset([gt_files[i] for i in tr_idx], mode='synthetic', crop=a.crop),
    ]

    if a.extra_dir:
        extra = []
        for e in IMG_EXT + ('.npy',):
            extra += glob.glob(os.path.join(a.extra_dir, '**', '*' + e), recursive=True)
        extra = sorted(set(extra))
        if extra:
            reps = max(1, a.extra_repeat)
            sets.append(PairDataset(extra * reps, mode='synthetic', crop=a.crop))
            print(f'  outside photos: {len(extra)} x{reps} = {len(extra) * reps}')
        else:
            print(f'  WARNING: no images found under {a.extra_dir}')

    train_ds = ConcatDataset(sets)
    # Validation uses KLA's REAL damaged files -- the honest measure.
    val_ds = PairDataset([gt_files[i] for i in va_idx], [lr_files[i] for i in va_idx],
                         mode='real', crop=None, augment=False, seed=1234)

    pin = torch.cuda.is_available()
    train_dl = DataLoader(train_ds, batch_size=a.batch, shuffle=True,
                          num_workers=a.workers, pin_memory=pin, drop_last=True,
                          persistent_workers=a.workers > 0)
    val_dl = DataLoader(val_ds, batch_size=max(1, a.batch // 2), shuffle=False,
                        num_workers=a.workers, pin_memory=pin)
    print(f'  training samples per epoch: {len(train_ds)}')
    return train_dl, val_dl


CFGS = {
    'w16': dict(width=16, middle_blk_num=4, enc_blk_nums=(1, 1, 2, 4),
                dec_blk_nums=(1, 1, 1, 1)),
    'w32': dict(width=32, middle_blk_num=12, enc_blk_nums=(2, 2, 4, 8),
                dec_blk_nums=(2, 2, 2, 2)),
    'w64': dict(width=64, middle_blk_num=12, enc_blk_nums=(2, 2, 4, 8),
                dec_blk_nums=(2, 2, 2, 2)),
}


def run(a):
    device = get_device()
    print(f'device: {device}')
    torch.manual_seed(0)
    if device.type == 'cuda':
        torch.backends.cudnn.benchmark = True

    train_dl, val_dl = build_loaders(a)

    cfg = CFGS[a.size]
    model = NAFNetSR(img_channel=1, scale=2, use_log_channel=True, **cfg).to(device)
    print(f'model: NAFNet-SR {a.size}, '
          f'{sum(p.numel() for p in model.parameters()) / 1e6:.2f}M parameters')

    crit = TotalLoss(a.w_fft, a.w_ssim)
    opt = torch.optim.AdamW(model.parameters(), lr=a.lr, weight_decay=1e-4,
                            betas=(0.9, 0.9))
    sched = torch.optim.lr_scheduler.CosineAnnealingLR(opt, T_max=a.epochs,
                                                       eta_min=a.lr * 0.01)
    # Pick the right half-precision type for the actual GPU.
    #   bf16 needs Ampere (compute 8.0+): A100, L4, RTX 30xx/40xx, H100
    #   fp16 is the right choice on Turing (7.5): the T4 that Kaggle gives you
    # Using bf16 on a T4 technically runs but falls back to slow software paths.
    use_amp = device.type == 'cuda'
    amp_dtype = torch.float16
    if use_amp:
        major, _ = torch.cuda.get_device_capability()
        amp_dtype = torch.bfloat16 if major >= 8 else torch.float16
        print(f'GPU: {torch.cuda.get_device_name(0)}  ->  using '
              f'{"bfloat16" if amp_dtype is torch.bfloat16 else "float16"}')
    # GradScaler is required for fp16 (it stops small gradients underflowing);
    # harmless with bf16.
    scaler = torch.amp.GradScaler('cuda', enabled=use_amp and amp_dtype is torch.float16)

    os.makedirs(a.out, exist_ok=True)
    bp, bs = baseline_scores(val_dl, device)
    print(f'\nbicubic baseline on val: PSNR {bp:.2f} dB   SSIM {bs:.4f}')
    print('your model must beat this.\n')

    best = -1e9
    for ep in range(1, a.epochs + 1):
        t0 = time.time()
        tot, nb = 0.0, 0
        for lr_img, gt in train_dl:
            lr_img = lr_img.to(device, non_blocking=True)
            gt = gt.to(device, non_blocking=True)
            opt.zero_grad(set_to_none=True)
            with torch.amp.autocast('cuda', dtype=amp_dtype, enabled=use_amp):
                loss = crit(model(lr_img), gt)
            if scaler.is_enabled():
                scaler.scale(loss).backward()
                scaler.unscale_(opt)
                torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
                scaler.step(opt)
                scaler.update()
            else:
                loss.backward()
                torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
                opt.step()
            tot += float(loss.detach())
            nb += 1
        sched.step()

        vp, vs = validate(model, val_dl, device)
        flag = ''
        if vp > best:
            best = vp
            torch.save({'model': model.state_dict(), 'cfg': cfg, 'size': a.size,
                        'epoch': ep, 'val_psnr': vp, 'val_ssim': vs},
                       os.path.join(a.out, 'best.pt'))
            flag = '   <- best, saved'
        torch.save({'model': model.state_dict(), 'cfg': cfg, 'size': a.size,
                    'epoch': ep}, os.path.join(a.out, 'last.pt'))
        print(f'epoch {ep:>3}/{a.epochs}  loss {tot / max(nb, 1):.4f}  '
              f'val PSNR {vp:.2f} (+{vp - bp:.2f} vs bicubic)  SSIM {vs:.4f}  '
              f'{time.time() - t0:.0f}s{flag}')

    print(f'\nbest val PSNR {best:.2f} dB -> {os.path.join(a.out, "best.pt")}')


def smoke_test():
    """Trains briefly on made-up data. Proves the whole pipeline runs."""
    print('SMOKE TEST -- fake data, 2 epochs, just checking nothing is broken.\n')
    import tempfile
    from PIL import Image
    d = tempfile.mkdtemp()
    gd, ld, ed = (os.path.join(d, x) for x in ('gt', 'lr', 'extra'))
    for p in (gd, ld, ed):
        os.makedirs(p)
    rng = np.random.default_rng(0)
    for i in range(12):
        base = rng.random((16, 16)).astype(np.float32)
        g = minmax(np.asarray(Image.fromarray(base).resize((256, 256), Image.BICUBIC))
                   .astype(np.float64))
        lr, _ = degrade(g, rng=rng)
        np.save(os.path.join(gd, f'{i:06d}.npy'), g.astype(np.float32))
        np.save(os.path.join(ld, f'{i:06d}.npy'), lr.astype(np.float32))
    for i in range(6):
        Image.fromarray((rng.random((400, 400)) * 255).astype(np.uint8)).save(
            os.path.join(ed, f'x{i}.png'))
    json.dump({'train': list(range(9)), 'val_hard': [9, 10, 11], 'val_easy': []},
              open(os.path.join(d, 'split.json'), 'w'))

    run(argparse.Namespace(
        gt_dir=gd, lr_dir=ld, split=os.path.join(d, 'split.json'), extra_dir=ed,
        extra_repeat=2, crop=256, size='w16', epochs=2, batch=2, lr=1e-3,
        workers=0, w_fft=0.05, w_ssim=0.10, out=os.path.join(d, 'ckpt')))
    print('\nSmoke test done. Two epochs and a saved checkpoint = pipeline works.')


if __name__ == '__main__':
    p = argparse.ArgumentParser()
    p.add_argument('--gt_dir')
    p.add_argument('--lr_dir')
    p.add_argument('--split', default='split.json')
    p.add_argument('--extra_dir', help='folder of outside photos, e.g. DIV2K_train_HR')
    p.add_argument('--extra_repeat', type=int, default=4,
                   help='random crops taken per outside photo, per epoch')
    p.add_argument('--crop', type=int, default=256)
    p.add_argument('--size', default='w32', choices=['w16', 'w32', 'w64'])
    p.add_argument('--epochs', type=int, default=60)
    p.add_argument('--batch', type=int, default=16)
    p.add_argument('--lr', type=float, default=1e-3)
    p.add_argument('--workers', type=int, default=4)
    p.add_argument('--w_fft', type=float, default=0.05)
    p.add_argument('--w_ssim', type=float, default=0.10)
    p.add_argument('--out', default='checkpoints')
    p.add_argument('--smoke_test', action='store_true')
    a = p.parse_args()
    if a.smoke_test:
        smoke_test()
    elif not a.gt_dir or not a.lr_dir:
        p.error('need --gt_dir and --lr_dir (or --smoke_test)')
    else:
        run(a)
# Out:
# Overwriting train.py

# %%
BASE = '/kaggle/input/datasets/aarushsingh2007/kla-dataset'
# !cp {BASE}/files/nafnet_sr.py {BASE}/files/make_training_data.py .
# !ls *.py
# Out:
# make_training_data.py  nafnet_sr.py  train.py

# %%
# %%writefile train.py
"""
Trains NAFNet-SR for the KLA image restoration challenge.

What it trains on
-----------------
Three sources, mixed together every epoch:

  1. KLA's real pairs, used exactly as given. Keeps you anchored to the truth.
  2. KLA's clean images, re-damaged fresh each time with random settings.
  3. Outside photos (DIV2K etc.), also damaged fresh each time.

Sources 2 and 3 are what make the model cope with images it has never seen,
which is half the score. Source 1 stops it drifting away from the real problem.

How it is scored while training
-------------------------------
Validation always uses KLA's REAL damaged files, never synthetic ones, on the
photos held out by day1_setup.py. That number is the honest one.

Run it
------
    python train.py --smoke_test        # ~1 minute, checks everything works

    python train.py --gt_dir GT --lr_dir NoisyLR --split split.json \
                    --extra_dir DIV2K_train_HR --size w32 --epochs 60
"""

import argparse
import glob
import json
import os
import time

import numpy as np
import torch
import torch.nn.functional as F
from torch.utils.data import ConcatDataset, DataLoader, Dataset

from make_training_data import degrade, minmax
from nafnet_sr import NAFNetSR, get_device

IMG_EXT = ('.png', '.jpg', '.jpeg', '.bmp', '.tif', '.tiff')


# ----------------------------------------------------------------------
# data
# ----------------------------------------------------------------------

def load_gray(path):
    """Load a .npy array or an ordinary image file as greyscale floats."""
    if path.lower().endswith('.npy'):
        a = np.load(path).astype(np.float64)
    else:
        from PIL import Image
        a = np.asarray(Image.open(path).convert('L')).astype(np.float64) / 255.0
    return np.nan_to_num(a, nan=0.0, posinf=0.0, neginf=0.0)


class PairDataset(Dataset):
    """mode='real'      -> KLA's own damaged files, untouched
       mode='synthetic' -> clean image damaged fresh on every access
    """

    def __init__(self, gt_paths, lr_paths=None, mode='synthetic',
                 crop=256, augment=True, seed=None):
        self.gt = list(gt_paths)
        self.lr = list(lr_paths) if lr_paths else None
        self.mode = mode
        self.crop = crop
        self.augment = augment
        self.seed = seed
        if mode == 'real' and not self.lr:
            raise ValueError("mode='real' needs lr_paths")

    def __len__(self):
        return len(self.gt)

    def __getitem__(self, i):
        # A fixed seed makes validation identical every epoch, so the numbers are
        # comparable run to run. Training leaves it None so the noise is fresh.
        rng = (np.random.default_rng(self.seed + i) if self.seed is not None
               else np.random.default_rng())

        gt = load_gray(self.gt[i])

        if self.mode == 'real':
            lr = load_gray(self.lr[i])
        else:
            if self.crop and min(gt.shape) > self.crop:
                y = int(rng.integers(0, gt.shape[0] - self.crop + 1))
                x = int(rng.integers(0, gt.shape[1] - self.crop + 1))
                gt = gt[y:y + self.crop, x:x + self.crop]
            # Every GT image KLA supplied is stretched to exactly [0,1].
            # Matching that keeps synthetic pairs statistically identical.
            gt = minmax(gt)
            lr, _ = degrade(gt, rng=rng, blur=bool(rng.random() < 0.1))

        if self.augment:
            if rng.random() < 0.5:
                gt, lr = gt[:, ::-1], lr[:, ::-1]
            if rng.random() < 0.5:
                gt, lr = gt[::-1], lr[::-1]
            k = int(rng.integers(4))
            if k:
                gt, lr = np.rot90(gt, k), np.rot90(lr, k)

        gt = torch.from_numpy(np.ascontiguousarray(gt, dtype=np.float32))[None]
        lr = torch.from_numpy(np.ascontiguousarray(lr, dtype=np.float32))[None]
        return lr, gt


# ----------------------------------------------------------------------
# losses and metrics
# ----------------------------------------------------------------------

class Charbonnier(torch.nn.Module):
    """Smoothed absolute error. Steadier than squared error, sharper than plain L1."""

    def __init__(self, eps=1e-3):
        super().__init__()
        self.e2 = eps ** 2

    def forward(self, p, t):
        return torch.sqrt((p - t) ** 2 + self.e2).mean()


def fft_loss(pred, target):
    """Compares the two images by their frequency content.

    This is what stops the model cheating. Blurring is an easy way to make grain
    vanish, and pixel losses barely punish it. Blurring destroys high frequencies,
    which this term notices immediately.
    """
    pf = torch.fft.rfft2(pred.float(), norm='ortho')
    tf = torch.fft.rfft2(target.float(), norm='ortho')
    return (torch.view_as_real(pf) - torch.view_as_real(tf)).abs().mean()


def _gauss_window(ws=11, sigma=1.5, device='cpu', dtype=torch.float32):
    c = torch.arange(ws, device=device, dtype=dtype) - (ws - 1) / 2
    g = torch.exp(-(c ** 2) / (2 * sigma ** 2))
    g = g / g.sum()
    return (g[:, None] @ g[None, :])[None, None]


def ssim(pred, target, ws=11, C1=0.01 ** 2, C2=0.03 ** 2):
    """Structural similarity, one of the three scores KLA uses. 1.0 is perfect."""
    pred, target = pred.float(), target.float()
    w = _gauss_window(ws, device=pred.device, dtype=pred.dtype)
    pad = ws // 2
    mu1 = F.conv2d(pred, w, padding=pad)
    mu2 = F.conv2d(target, w, padding=pad)
    mu1s, mu2s, mu12 = mu1 ** 2, mu2 ** 2, mu1 * mu2
    s1 = F.conv2d(pred * pred, w, padding=pad) - mu1s
    s2 = F.conv2d(target * target, w, padding=pad) - mu2s
    s12 = F.conv2d(pred * target, w, padding=pad) - mu12
    num = (2 * mu12 + C1) * (2 * s12 + C2)
    den = (mu1s + mu2s + C1) * (s1 + s2 + C2)
    return (num / den).mean()


def psnr(pred, target):
    """Higher is better; +1 dB is a solid gain.

    Clamped to [0,1] first because every KLA ground-truth image lives in exactly
    that range, so anything outside it is pure error.
    """
    mse = F.mse_loss(pred.clamp(0, 1).float(), target.float())
    return 10 * torch.log10(1.0 / mse.clamp_min(1e-12))


class TotalLoss(torch.nn.Module):
    def __init__(self, w_fft=0.05, w_ssim=0.10):
        super().__init__()
        self.char = Charbonnier()
        self.w_fft = w_fft
        self.w_ssim = w_ssim

    def forward(self, pred, target):
        loss = self.char(pred, target)
        if self.w_fft:
            loss = loss + self.w_fft * fft_loss(pred, target)
        if self.w_ssim:
            loss = loss + self.w_ssim * (1 - ssim(pred.clamp(0, 1), target))
        return loss


# ----------------------------------------------------------------------
# train / validate
# ----------------------------------------------------------------------

class EMA:
    """Keeps a slow-moving average of the weights, and scores THAT.

    Individual training steps jitter the weights around the good solution. The
    average sits much closer to the middle of it, so it scores better and, more
    importantly, stops the epoch-to-epoch bouncing that made the last run's
    validation swing by 0.5 dB and then fall apart near the end.

    Standard practice in image restoration; typically worth 0.1-0.3 dB on its own.
    """

    def __init__(self, model, decay=0.999):
        self.decay = decay
        self.shadow = {k: v.detach().clone().float()
                       for k, v in model.state_dict().items()
                       if v.dtype.is_floating_point}
        self.backup = {}

    @torch.no_grad()
    def update(self, model):
        for k, v in model.state_dict().items():
            if k in self.shadow:
                self.shadow[k].mul_(self.decay).add_(v.detach().float(),
                                                     alpha=1 - self.decay)

    def apply_to(self, model):
        self.backup = {k: v.detach().clone() for k, v in model.state_dict().items()
                       if k in self.shadow}
        model.load_state_dict({k: v.to(dtype=model.state_dict()[k].dtype)
                               for k, v in self.shadow.items()}, strict=False)

    def restore(self, model):
        if self.backup:
            model.load_state_dict(self.backup, strict=False)
            self.backup = {}


@torch.no_grad()
def validate(model, loader, device):
    model.eval()
    ps, ss, n = 0.0, 0.0, 0
    for lr, gt in loader:
        lr, gt = lr.to(device), gt.to(device)
        out = model(lr).clamp(0, 1)
        b = lr.shape[0]
        ps += float(psnr(out, gt)) * b
        ss += float(ssim(out, gt)) * b
        n += b
    model.train()
    return ps / max(n, 1), ss / max(n, 1)


@torch.no_grad()
def baseline_scores(loader, device, scale=2):
    """What plain bicubic upscaling gets. The model must beat this, or something
    is broken. Cheapest possible sanity check."""
    ps, ss, n = 0.0, 0.0, 0
    for lr, gt in loader:
        lr, gt = lr.to(device), gt.to(device)
        up = F.interpolate(lr, scale_factor=scale, mode='bicubic',
                           align_corners=False).clamp(0, 1)
        b = lr.shape[0]
        ps += float(psnr(up, gt)) * b
        ss += float(ssim(up, gt)) * b
        n += b
    return ps / max(n, 1), ss / max(n, 1)


def build_loaders(a):
    gt_files = sorted(glob.glob(os.path.join(a.gt_dir, '*.npy')))
    lr_files = [os.path.join(a.lr_dir, os.path.basename(f)) for f in gt_files]
    keep = [i for i, f in enumerate(lr_files) if os.path.exists(f)]
    gt_files = [gt_files[i] for i in keep]
    lr_files = [lr_files[i] for i in keep]
    if not gt_files:
        raise SystemExit('No matching GT / NoisyLR pairs found. Check the paths.')

    split = json.load(open(a.split))
    tr_idx = [i for i in split['train'] if i < len(gt_files)]
    va_idx = [i for i in split['val_hard'] if i < len(gt_files)]
    print(f'  KLA pairs: {len(gt_files)}  ->  train {len(tr_idx)}, val {len(va_idx)}')

    sets = [
        # 1. the real pairs, untouched
        PairDataset([gt_files[i] for i in tr_idx], [lr_files[i] for i in tr_idx],
                    mode='real', crop=None),
        # 2. the same clean images, re-damaged fresh every time
        PairDataset([gt_files[i] for i in tr_idx], mode='synthetic', crop=a.crop),
    ]

    if a.extra_dir:
        extra = []
        for e in IMG_EXT + ('.npy',):
            extra += glob.glob(os.path.join(a.extra_dir, '**', '*' + e), recursive=True)
        extra = sorted(set(extra))
        if extra:
            reps = max(1, a.extra_repeat)
            sets.append(PairDataset(extra * reps, mode='synthetic', crop=a.crop))
            print(f'  outside photos: {len(extra)} x{reps} = {len(extra) * reps}')
        else:
            print(f'  WARNING: no images found under {a.extra_dir}')

    train_ds = ConcatDataset(sets)
    # Validation uses KLA's REAL damaged files -- the honest measure.
    val_ds = PairDataset([gt_files[i] for i in va_idx], [lr_files[i] for i in va_idx],
                         mode='real', crop=None, augment=False, seed=1234)

    pin = torch.cuda.is_available()
    train_dl = DataLoader(train_ds, batch_size=a.batch, shuffle=True,
                          num_workers=a.workers, pin_memory=pin, drop_last=True,
                          persistent_workers=a.workers > 0)
    val_dl = DataLoader(val_ds, batch_size=max(1, a.batch // 2), shuffle=False,
                        num_workers=a.workers, pin_memory=pin)
    print(f'  training samples per epoch: {len(train_ds)}')
    return train_dl, val_dl


CFGS = {
    'w16': dict(width=16, middle_blk_num=4, enc_blk_nums=(1, 1, 2, 4),
                dec_blk_nums=(1, 1, 1, 1)),
    'w32': dict(width=32, middle_blk_num=12, enc_blk_nums=(2, 2, 4, 8),
                dec_blk_nums=(2, 2, 2, 2)),
    'w64': dict(width=64, middle_blk_num=12, enc_blk_nums=(2, 2, 4, 8),
                dec_blk_nums=(2, 2, 2, 2)),
}


def run(a):
    device = get_device()
    print(f'device: {device}')
    torch.manual_seed(0)
    if device.type == 'cuda':
        torch.backends.cudnn.benchmark = True

    train_dl, val_dl = build_loaders(a)

    cfg = CFGS[a.size]
    model = NAFNetSR(img_channel=1, scale=2, use_log_channel=True, **cfg).to(device)
    print(f'model: NAFNet-SR {a.size}, '
          f'{sum(p.numel() for p in model.parameters()) / 1e6:.2f}M parameters')

    crit = TotalLoss(a.w_fft, a.w_ssim)
    # beta2=0.999, not NAFNet's 0.9. Their 0.9 makes Adam's variance estimate very
    # noisy; it works for them with long warmups and huge batches, but here it is
    # the most likely cause of the last run's unstable, drifting late epochs.
    opt = torch.optim.AdamW(model.parameters(), lr=a.lr, weight_decay=1e-4,
                            betas=(0.9, a.beta2))
    sched = torch.optim.lr_scheduler.CosineAnnealingLR(opt, T_max=a.epochs,
                                                       eta_min=a.lr * 0.01)
    ema = EMA(model, decay=a.ema) if a.ema > 0 else None
    warmup_steps = a.warmup
    step = 0
    # Pick the right half-precision type for the actual GPU.
    #   bf16 needs Ampere (compute 8.0+): A100, L4, RTX 30xx/40xx, H100
    #   fp16 is the right choice on Turing (7.5): the T4 that Kaggle gives you
    # Using bf16 on a T4 technically runs but falls back to slow software paths.
    use_amp = device.type == 'cuda'
    amp_dtype = torch.float16
    if use_amp:
        major, _ = torch.cuda.get_device_capability()
        amp_dtype = torch.bfloat16 if major >= 8 else torch.float16
        print(f'GPU: {torch.cuda.get_device_name(0)}  ->  using '
              f'{"bfloat16" if amp_dtype is torch.bfloat16 else "float16"}')
    # GradScaler is required for fp16 (it stops small gradients underflowing);
    # harmless with bf16.
    scaler = torch.amp.GradScaler('cuda', enabled=use_amp and amp_dtype is torch.float16)

    os.makedirs(a.out, exist_ok=True)
    bp, bs = baseline_scores(val_dl, device)
    print(f'\nbicubic baseline on val: PSNR {bp:.2f} dB   SSIM {bs:.4f}')
    print('your model must beat this.\n')

    best = -1e9
    for ep in range(1, a.epochs + 1):
        t0 = time.time()
        tot, nb = 0.0, 0
        for lr_img, gt in train_dl:
            # Gentle start: ramp the learning rate up over the first few hundred
            # steps so the very first updates cannot throw the weights off.
            if step < warmup_steps:
                for g in opt.param_groups:
                    g['lr'] = a.lr * (step + 1) / warmup_steps
            step += 1

            lr_img = lr_img.to(device, non_blocking=True)
            gt = gt.to(device, non_blocking=True)
            opt.zero_grad(set_to_none=True)
            with torch.amp.autocast('cuda', dtype=amp_dtype, enabled=use_amp):
                loss = crit(model(lr_img), gt)
            if scaler.is_enabled():
                scaler.scale(loss).backward()
                scaler.unscale_(opt)
                torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
                scaler.step(opt)
                scaler.update()
            else:
                loss.backward()
                torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
                opt.step()
            if ema is not None:
                ema.update(model)
            tot += float(loss.detach())
            nb += 1
        if step >= warmup_steps:
            sched.step()

        # Score the averaged weights, and save those too -- they are what you ship.
        if ema is not None:
            ema.apply_to(model)
        vp, vs = validate(model, val_dl, device)
        flag = ''
        if vp > best:
            best = vp
            torch.save({'model': model.state_dict(), 'cfg': cfg, 'size': a.size,
                        'epoch': ep, 'val_psnr': vp, 'val_ssim': vs},
                       os.path.join(a.out, 'best.pt'))
            flag = '   <- best, saved'
        torch.save({'model': model.state_dict(), 'cfg': cfg, 'size': a.size,
                    'epoch': ep}, os.path.join(a.out, 'last.pt'))
        if ema is not None:
            ema.restore(model)
        print(f'epoch {ep:>3}/{a.epochs}  loss {tot / max(nb, 1):.4f}  '
              f'val PSNR {vp:.2f} (+{vp - bp:.2f} vs bicubic)  SSIM {vs:.4f}  '
              f'{time.time() - t0:.0f}s{flag}')

    print(f'\nbest val PSNR {best:.2f} dB -> {os.path.join(a.out, "best.pt")}')


def smoke_test():
    """Trains briefly on made-up data. Proves the whole pipeline runs."""
    print('SMOKE TEST -- fake data, 2 epochs, just checking nothing is broken.\n')
    import tempfile
    from PIL import Image
    d = tempfile.mkdtemp()
    gd, ld, ed = (os.path.join(d, x) for x in ('gt', 'lr', 'extra'))
    for p in (gd, ld, ed):
        os.makedirs(p)
    rng = np.random.default_rng(0)
    for i in range(12):
        base = rng.random((16, 16)).astype(np.float32)
        g = minmax(np.asarray(Image.fromarray(base).resize((256, 256), Image.BICUBIC))
                   .astype(np.float64))
        lr, _ = degrade(g, rng=rng)
        np.save(os.path.join(gd, f'{i:06d}.npy'), g.astype(np.float32))
        np.save(os.path.join(ld, f'{i:06d}.npy'), lr.astype(np.float32))
    for i in range(6):
        Image.fromarray((rng.random((400, 400)) * 255).astype(np.uint8)).save(
            os.path.join(ed, f'x{i}.png'))
    json.dump({'train': list(range(9)), 'val_hard': [9, 10, 11], 'val_easy': []},
              open(os.path.join(d, 'split.json'), 'w'))

    run(argparse.Namespace(
        gt_dir=gd, lr_dir=ld, split=os.path.join(d, 'split.json'), extra_dir=ed,
        extra_repeat=2, crop=256, size='w16', epochs=2, batch=2, lr=1e-3,
        beta2=0.999, ema=0.99, warmup=5, workers=0, w_fft=0.05, w_ssim=0.10,
        out=os.path.join(d, 'ckpt')))
    print('\nSmoke test done. Two epochs and a saved checkpoint = pipeline works.')


if __name__ == '__main__':
    p = argparse.ArgumentParser()
    p.add_argument('--gt_dir')
    p.add_argument('--lr_dir')
    p.add_argument('--split', default='split.json')
    p.add_argument('--extra_dir', help='folder of outside photos, e.g. DIV2K_train_HR')
    p.add_argument('--extra_repeat', type=int, default=4,
                   help='random crops taken per outside photo, per epoch')
    p.add_argument('--crop', type=int, default=256)
    p.add_argument('--size', default='w32', choices=['w16', 'w32', 'w64'])
    p.add_argument('--epochs', type=int, default=60)
    p.add_argument('--batch', type=int, default=16)
    p.add_argument('--lr', type=float, default=5e-4)
    p.add_argument('--beta2', type=float, default=0.999)
    p.add_argument('--ema', type=float, default=0.999,
                   help='weight-averaging decay; 0 turns it off')
    p.add_argument('--warmup', type=int, default=500,
                   help='steps to ramp the learning rate up over')
    p.add_argument('--workers', type=int, default=4)
    p.add_argument('--w_fft', type=float, default=0.05)
    p.add_argument('--w_ssim', type=float, default=0.10)
    p.add_argument('--out', default='checkpoints')
    p.add_argument('--smoke_test', action='store_true')
    a = p.parse_args()
    if a.smoke_test:
        smoke_test()
    elif not a.gt_dir or not a.lr_dir:
        p.error('need --gt_dir and --lr_dir (or --smoke_test)')
    else:
        run(a)
# Out:
# Overwriting train.py

# %%
# !grep -c "class EMA" train.py
# Out:
# 1

# %%
# !python train.py \
  --gt_dir {BASE}/train/train/GT \
  --lr_dir {BASE}/train/train/NoisyLR \
  --split {BASE}/split.json \
  --extra_dir {BASE}/DIV2K_train_HR/DIV2K_train_HR \
  --size w32 --epochs 40 --batch 16 --workers 4 \
  --out /kaggle/working/checkpoints_v2
# Out:
# device: cuda
#   KLA pairs: 3200  ->  train 2720, val 480
#   outside photos: 800 x4 = 3200
#   training samples per epoch: 8640
# model: NAFNet-SR w32, 29.16M parameters
# GPU: Tesla T4  ->  using float16
#
# bicubic baseline on val: PSNR 22.15 dB   SSIM 0.5410
# your model must beat this.
#
# epoch   1/40  loss 0.0925  val PSNR 22.89 (+0.74 vs bicubic)  SSIM 0.5653  243s   <- best, saved
# epoch   2/40  loss 0.0838  val PSNR 23.69 (+1.54 vs bicubic)  SSIM 0.5938  212s   <- best, saved
# epoch   3/40  loss 0.0816  val PSNR 24.44 (+2.30 vs bicubic)  SSIM 0.6288  212s   <- best, saved
# epoch   4/40  loss 0.0798  val PSNR 24.82 (+2.68 vs bicubic)  SSIM 0.6495  213s   <- best, saved
# epoch   5/40  loss 0.0786  val PSNR 25.11 (+2.97 vs bicubic)  SSIM 0.6613  214s   <- best, saved
# epoch   6/40  loss 0.0780  val PSNR 25.27 (+3.13 vs bicubic)  SSIM 0.6686  214s   <- best, saved
# epoch   7/40  loss 0.0777  val PSNR 25.35 (+3.21 vs bicubic)  SSIM 0.6735  213s   <- best, saved
# epoch   8/40  loss 0.0773  val PSNR 25.37 (+3.23 vs bicubic)  SSIM 0.6743  214s   <- best, saved
# epoch   9/40  loss 0.0771  val PSNR 25.40 (+3.25 vs bicubic)  SSIM 0.6753  214s   <- best, saved
# epoch  10/40  loss 0.0773  val PSNR 25.42 (+3.27 vs bicubic)  SSIM 0.6763  214s   <- best, saved
# epoch  11/40  loss 0.0760  val PSNR 25.41 (+3.26 vs bicubic)  SSIM 0.6754  213s
# epoch  12/40  loss 0.0767  val PSNR 25.41 (+3.26 vs bicubic)  SSIM 0.6757  212s
# epoch  13/40  loss 0.0755  val PSNR 25.42 (+3.27 vs bicubic)  SSIM 0.6760  214s   <- best, saved
# epoch  14/40  loss 0.0760  val PSNR 25.44 (+3.29 vs bicubic)  SSIM 0.6771  213s   <- best, saved
# epoch  15/40  loss 0.0753  val PSNR 25.42 (+3.27 vs bicubic)  SSIM 0.6755  213s
# epoch  16/40  loss 0.0751  val PSNR 25.44 (+3.29 vs bicubic)  SSIM 0.6772  212s
# epoch  17/40  loss 0.0750  val PSNR 25.45 (+3.30 vs bicubic)  SSIM 0.6785  214s   <- best, saved
# epoch  18/40  loss 0.0748  val PSNR 25.47 (+3.33 vs bicubic)  SSIM 0.6802  214s   <- best, saved
# epoch  19/40  loss 0.0746  val PSNR 25.48 (+3.33 vs bicubic)  SSIM 0.6808  212s   <- best, saved
# epoch  20/40  loss 0.0750  val PSNR 25.49 (+3.35 vs bicubic)  SSIM 0.6823  212s   <- best, saved
# epoch  21/40  loss 0.0743  val PSNR 25.50 (+3.35 vs bicubic)  SSIM 0.6827  213s   <- best, saved
# epoch  22/40  loss 0.0732  val PSNR 25.50 (+3.36 vs bicubic)  SSIM 0.6835  213s   <- best, saved
# epoch  23/40  loss 0.0740  val PSNR 25.49 (+3.35 vs bicubic)  SSIM 0.6833  212s
# epoch  24/40  loss 0.0733  val PSNR 25.50 (+3.35 vs bicubic)  SSIM 0.6836  213s
# epoch  25/40  loss 0.0734  val PSNR 25.50 (+3.36 vs bicubic)  SSIM 0.6848  213s   <- best, saved
# epoch  26/40  loss 0.0732  val PSNR 25.51 (+3.36 vs bicubic)  SSIM 0.6859  213s   <- best, saved
# epoch  27/40  loss 0.0733  val PSNR 25.50 (+3.35 vs bicubic)  SSIM 0.6865  213s
# epoch  28/40  loss 0.0729  val PSNR 25.49 (+3.34 vs bicubic)  SSIM 0.6865  214s
# epoch  29/40  loss 0.0726  val PSNR 25.48 (+3.34 vs bicubic)  SSIM 0.6874  213s
# epoch  30/40  loss 0.0731  val PSNR 25.45 (+3.31 vs bicubic)  SSIM 0.6881  212s
# epoch  31/40  loss 0.0731  val PSNR 25.41 (+3.26 vs bicubic)  SSIM 0.6883  212s
# epoch  32/40  loss 0.0741  val PSNR 25.34 (+3.19 vs bicubic)  SSIM 0.6886  212s
# epoch  33/40  loss 0.0733  val PSNR 25.33 (+3.18 vs bicubic)  SSIM 0.6873  211s
# epoch  34/40  loss 0.0733  val PSNR 25.31 (+3.16 vs bicubic)  SSIM 0.6874  212s
# epoch  35/40  loss 0.0734  val PSNR 25.30 (+3.15 vs bicubic)  SSIM 0.6873  212s
# epoch  36/40  loss 0.0737  val PSNR 25.26 (+3.12 vs bicubic)  SSIM 0.6869  212s
# epoch  37/40  loss 0.0736  val PSNR 25.25 (+3.10 vs bicubic)  SSIM 0.6870  213s
# epoch  38/40  loss 0.0741  val PSNR 25.22 (+3.07 vs bicubic)  SSIM 0.6866  213s
# epoch  39/40  loss 0.0745  val PSNR 25.18 (+3.03 vs bicubic)  SSIM 0.6861  213s
# epoch  40/40  loss 0.0744  val PSNR 25.15 (+3.00 vs bicubic)  SSIM 0.6862  212s
#
# best val PSNR 25.51 dB -> /kaggle/working/checkpoints_v2/best.pt
